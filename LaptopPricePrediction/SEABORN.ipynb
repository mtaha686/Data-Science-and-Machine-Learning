# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('Preprocessed_Laptop_data.csv')

# %%
df.drop(['Unnamed: 0'],axis =1, inplace=True)

# %%
df.head()
# Out:
#   Company   TypeName  Ram    Gpu  OpSys  Weight        Price  TouchScreen  \
# 0   Apple  Ultrabook    8  Intel  macOS    1.37   71378.6832            0
# 1   Apple  Ultrabook    8  Intel  macOS    1.34   47895.5232            0
# 2      HP   Notebook    8  Intel     No    1.86   30636.0000            0
# 3   Apple  Ultrabook   16    AMD  macOS    1.83  135195.3360            0
# 4   Apple  Ultrabook    8  Intel  macOS    1.37   96095.8080            0
#
#    IPS         PPI            CPU  SSD  HDD
# 0    1  226.983005  Intel Core i5  128    0
# 1    0  127.677940  Intel Core i5    0    0
# 2    0  141.211998  Intel Core i5  256    0
# 3    1  220.534624  Intel Core i7  512    0
# 4    1  226.983005  Intel Core i5  256    0

# %%
X= df.drop(['Price'],axis =1)
y = df['Price']

# %% [markdown]
# ## Line plot

# %%
sns.set(style="whitegrid")
plt.figure(figsize=(8, 4))
sns.lineplot(x=df['SSD'], y=Y)
plt.title("Line Plot")
plt.show()

# %% [markdown]
# ## Scatter plot

# %%
plt.figure(figsize=(8, 4))
sns.scatterplot(x=df['SSD'], y=y , marker='o', color='red')
plt.title("Scatter Plot")
plt.show()

# %% [markdown]
# # Bar Plot

# %%
plt.figure(figsize=(8, 4))
sns.barplot(x=df['OpSys'], y=y)
plt.title("Bar Chart")
plt.show()

# %% [markdown]
# ## Histogram plot

# %%
plt.figure(figsize=(8, 4))
sns.histplot(data = df, x = y, kde=True)
plt.title("Histogram")
plt.show()

# %% [markdown]
# ## Violin Plot

# %%
plt.figure(figsize=(8, 4))
sns.violinplot(data = df,x = y, vertical=True)
plt.title("Violin Plot")
plt.show()

# %% [markdown]
# ## Heat Map

# %%
plt.figure(figsize=(8, 6))
sns.heatmap(df.corr(), cmap='viridis', annot=True)
plt.xticks(rotation='vertical')
plt.title("Heatmap")
plt.show()
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_5784\2612879241.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(), cmap='viridis', annot=True)
